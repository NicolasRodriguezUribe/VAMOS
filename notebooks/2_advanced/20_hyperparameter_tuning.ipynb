# %% [markdown]
# # Advanced Hyperparameter Tuning with Optuna
#
# This notebook uses **Optuna** through `ModelBasedTuner` to tune a custom NSGA-II search space.
#
# We will:
# 1. define a compact parameter space for NSGA-II,
# 2. run Optuna on ZDT1,
# 3. inspect the best configuration and convergence trace,
# 4. export the study history for later analysis.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from vamos import optimize
from vamos.algorithms import NSGAIIConfig
from vamos.engine.tuning import (
    EvalContext,
    Instance,
    Int,
    ModelBasedTuner,
    ParamSpace,
    Real,
    TuningTask,
    available_model_based_backends,
    save_history_csv,
    save_history_json,
)
from vamos.foundation.quality_indicators import compute_hypervolume

if not available_model_based_backends().get('optuna'):
    raise RuntimeError("Optuna is not available. Install vamos-optimization[tuning].")

# %% [markdown]
# ## 1. Define a Custom Search Space
#
# A manual `ParamSpace` is useful when you want a small, stable search space for a specific notebook or experiment.

# %%
param_space = ParamSpace(
    params={
        'pop_size': Int('pop_size', 60, 140),
        'crossover_prob': Real('crossover_prob', 0.70, 0.98),
        'crossover_eta': Real('crossover_eta', 8.0, 35.0),
        'mutation_eta': Real('mutation_eta', 8.0, 35.0),
    }
)

rng = np.random.default_rng(7)
for idx in range(3):
    print(f"Sample {idx + 1}: {param_space.sample(rng)}")

# %% [markdown]
# ## 2. Define the Evaluation Function
#
# The tuner explores dictionaries of hyperparameters. Here we convert each trial into an explicit `NSGAIIConfig` and score it with hypervolume.

# %%
REF_POINT = np.array([1.1, 1.1])


def eval_fn(config: dict, ctx: EvalContext) -> float:
    cfg = (
        NSGAIIConfig.builder()
        .pop_size(int(config['pop_size']))
        .selection('tournament', size=2)
        .crossover('sbx', prob=float(config['crossover_prob']), eta=float(config['crossover_eta']))
        .mutation('polynomial', prob='1/n', eta=float(config['mutation_eta']))
        .build()
    )

    result = optimize(
        ctx.instance.name,
        algorithm='nsgaii',
        algorithm_config=cfg,
        max_evaluations=ctx.budget,
        seed=ctx.seed,
        n_var=ctx.instance.n_var,
        engine='numpy',
    )

    if result.F is None or len(result.F) == 0:
        return 0.0
    return float(compute_hypervolume(result.F, REF_POINT))

# %% [markdown]
# ## 3. Build the Optuna Task
#
# `TuningTask` defines the search space, the training instances, the random seeds, and the score aggregation rule.

# %%
task = TuningTask(
    name='advanced_optuna_custom_space',
    param_space=param_space,
    instances=[Instance(name='zdt1', n_var=20, kwargs={})],
    seeds=[0, 1],
    budget_per_run=1500,
    maximize=True,
    aggregator=np.mean,
)

task

# %% [markdown]
# ## 4. Run Optuna
#
# We keep `n_jobs=1` here so the notebook stays deterministic for a fixed seed.

# %%
tuner = ModelBasedTuner(
    task=task,
    max_trials=10,
    backend='optuna',
    optuna_sampler='tpe',
    seed=42,
    n_jobs=1,
)

best_config, history = tuner.run(eval_fn, verbose=False)

print('Best configuration:')
for key, value in best_config.items():
    print(f'  {key}: {value}')
print(f'Trials collected: {len(history)}')

# %% [markdown]
# ## 5. Inspect the Results
#
# The `history` list contains the full Optuna trace. We can turn it into a DataFrame for quick inspection.

# %%
df = pd.DataFrame([
    {'trial_id': trial.trial_id, 'score': trial.score, **trial.config}
    for trial in history
]).sort_values('trial_id')

df.head()

# %%
best_so_far = np.maximum.accumulate(df['score'].to_numpy())

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

axes[0].plot(df['trial_id'], df['score'], 'o-', alpha=0.8, label='trial score')
axes[0].plot(df['trial_id'], best_so_far, linewidth=2.0, label='best so far')
axes[0].set_title('Optuna convergence trace')
axes[0].set_xlabel('Trial')
axes[0].set_ylabel('Hypervolume')
axes[0].legend()

axes[1].scatter(df['pop_size'], df['score'], c=df['crossover_eta'], cmap='viridis', s=70)
axes[1].set_title('Population size vs score')
axes[1].set_xlabel('pop_size')
axes[1].set_ylabel('Hypervolume')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Export History
#
# Exporting the trial history is useful when you want to compare runs outside the notebook or reuse the data in a report.

# %%
artifacts_dir = Path('results/notebooks/20_hyperparameter_tuning')
save_history_json(history, task.param_space, artifacts_dir / 'history.json', include_raw=True)
save_history_csv(history, task.param_space, artifacts_dir / 'history.csv', include_raw=True)

print(f'Artifacts written to: {artifacts_dir.resolve()}')

# %% [markdown]
# ## Next Steps
#
# - Continue with [21_programmatic_tuning.ipynb](./21_programmatic_tuning.ipynb) for a fuller Optuna workflow built on VAMOS' pre-defined config spaces.
# - Continue with [33_optuna_tuning_advanced.ipynb](./33_optuna_tuning_advanced.ipynb) for multi-fidelity, BOHB, and persistent Optuna studies.

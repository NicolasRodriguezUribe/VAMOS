# %% [markdown]
# # Search Dynamics
#
# Inspect how the returned front changes as the evaluation budget increases. This keeps the analysis on the current API and avoids the old archive-builder shorthand.

# %%
import matplotlib.pyplot as plt
import numpy as np

from vamos import optimize
from vamos.foundation.quality_indicators import compute_hypervolume

BUDGETS = [200, 500, 1000, 2000, 5000, 8000]
REF_POINT = np.array([1.1, 1.1])

snapshots = {}
for budget in BUDGETS:
    result = optimize("zdt1", algorithm="nsgaii", max_evaluations=budget, pop_size=100, seed=42)
    snapshots[budget] = result.F.copy()

# %%
fig, axes = plt.subplots(2, 3, figsize=(12, 8), sharex=True, sharey=True)
axes = axes.flatten()
f1_true = np.linspace(0, 1, 200)
f2_true = 1 - np.sqrt(f1_true)

for ax, budget in zip(axes, BUDGETS):
    F = snapshots[budget]
    ax.plot(f1_true, f2_true, "k--", alpha=0.5)
    ax.scatter(F[:, 0], F[:, 1], s=15, alpha=0.65)
    ax.set_title(f"budget={budget}")
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
hv_rows = []
for budget, F in snapshots.items():
    hv_rows.append((budget, compute_hypervolume(F, REF_POINT)))

hv_rows

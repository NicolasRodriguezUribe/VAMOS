# %% [markdown]
# # Tuning NSGA-II hyperparameters on ZDT1
#
# This notebook demonstrates how to run the built-in tuner to search NSGA-II hyperparameters on the ZDT1 problem.

# %%
# %load_ext autoreload
# %autoreload 2
import json
from pathlib import Path
import numpy as np

from vamos.engine.tuning import tune

from vamos.foundation.problem.registry import make_problem_selection
from vamos.foundation.core.runner import ExperimentConfig

# Set a deterministic seed for reproducibility
SEED = 42
OUT_DIR = Path("results/tuning_zdt1")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# Problem selection
selection = make_problem_selection("zdt1", n_var=30)
# Larger inner budget for serious tuning
base_config = ExperimentConfig(population_size=200, max_evaluations=40000, seed=SEED)

from vamos.engine.tuning import build_nsgaii_config_space

# Full hyperparameter space for NSGA-II (all continuous operators)
config_space = build_nsgaii_config_space()

print(config_space)
# Out:
# <vamos.engine.tuning.core.parameter_space.AlgorithmConfigSpace object at 0x0000023753C071A0>

# %%
# Run tuning (outer NSGA-II optimizing HV of inner NSGA-II configs)
# Higher meta budget for real search
tuning_results = tune(
    problem_selection=selection,
    base_config=base_config,
    config_space=config_space,
    n_generations=120,  # meta generations
    population_size=60,  # meta population
    seed=SEED,
    output_dir=OUT_DIR,
    verbose=True,
)

print(f"Evaluated {len(tuning_results['trials'])} configurations")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Run tuning (outer NSGA-II optimizing HV of inner NSGA-II configs)
#       2 # Higher meta budget for real search
# ----> 3 tuning_results = tune(
#       4     problem_selection=selection,
#       5     base_config=base_config,
#       6     config_space=config_space,
#       7     n_generations=120,  # meta generations
#       8     population_size=60,  # meta population
#       9     seed=SEED,
#      10     output_dir=OUT_DIR,
#      11     verbose=True,
#      12 )
#      14 print(f"Evaluated {len(tuning_results['trials'])} configurations")
#
# File ~\Desktop\VAMOS\src\vamos\tuning\__init__.py:64, in tune(problem_selection, base_config, config_space, n_generations, population_size, seed, output_dir, verbose)
#      51 problem = problem_selection.instantiate()
#      52 tuner = NSGAIITuner(
#      53     config_space=config_space,
#      54     problems=[problem],
#    (...)     62     seed=seed,
#      63 )
# ---> 64 X_meta, F_meta, configs, diagnostics = tuner.optimize()
#      65 configs_serializable = [_config_to_serializable(cfg) for cfg in configs]
#      66 # Meta objectives are minimized; quality is negative HV in slot 0.
#
# File ~\Desktop\VAMOS\src\vamos\tuning\tuner.py:81, in NSGAIITuner.optimize(self)
#      57 meta_problem = MetaOptimizationProblem(
#      58     self.config_space,
#      59     self.problems,
#    (...)     70     baseline_quality=self.baseline_quality,
#      71 )
#      72 meta_algo = MetaNSGAII(
#      73     meta_problem,
#      74     population_size=self.meta_population_size,
#    (...)     79     seed=algo_seed,
#      80 )
# ---> 81 X_meta, F_meta, diagnostics = meta_algo.run()
#      82 configs = [self.config_space.decode_vector(vec) for vec in X_meta]
#      83 return X_meta, F_meta, configs, diagnostics
#
# File ~\Desktop\VAMOS\src\vamos\tuning\nsga2_meta.py:59, in MetaNSGAII.run(self)
#      57 self.start_time = time.perf_counter()
#      58 X = self.rng.uniform(0.0, 1.0, size=(self.population_size, self.dim))
# ---> 59 F, evaluated = self._evaluate_population(X)
#      60 X = X[:evaluated]
#      61 if evaluated == 0:
#
# File ~\Desktop\VAMOS\src\vamos\tuning\nsga2_meta.py:97, in MetaNSGAII._evaluate_population(self, X)
#      95     value_arr = np.asarray(cached, dtype=float).ravel()
#      96 else:
# ---> 97     value = self.problem.evaluate(vec)
#      98     value_arr = np.asarray(value, dtype=float).ravel()
#      99     self.meta_eval_count += 1
#
# File ~\Desktop\VAMOS\src\vamos\tuning\meta_problem.py:94, in MetaOptimizationProblem.evaluate(self, x)
#      92 run_seed = int(self.meta_rng.integers(0, 2**32 - 1))
#      93 start_run = time.perf_counter()
# ---> 94 result = self._optimize(
#      95     problem, config, termination=termination, seed=run_seed, engine=self.engine
#      96 )
#      97 elapsed = time.perf_counter() - start_run
#      98 self.last_inner_runs += 1
#
# File ~\Desktop\VAMOS\src\vamos\optimize.py:37, in optimize(problem, config, termination, seed, engine)
#      34 else:
#      35     raise ValueError("optimize() currently supports NSGA-II configurations only.")
# ---> 37 result = algorithm.run(problem, termination=termination, seed=seed)
#      38 return OptimizationResult(result)
#
# File ~\Desktop\VAMOS\src\vamos\algorithm\nsgaii.py:157, in NSGAII.run(self, problem, termination, seed)
#     155 if crowd_archive is not None:
#     156     for xx, ff in zip(X, F):
# --> 157         crowd_archive.add(xx, ff)
#     158 if archive_size:
#     159     if archive_via_kernel:
#
# File ~\Desktop\VAMOS\src\vamos\algorithm\archive.py:56, in CrowdingArchive.add(self, x, f)
#      54 self.X.append(x_arr)
#      55 if len(self.F) > self.capacity:
# ---> 56     self._trim()
#
# File ~\Desktop\VAMOS\src\vamos\algorithm\archive.py:60, in CrowdingArchive._trim(self)
#      58 def _trim(self) -> None:
#      59     F = np.vstack(self.F)
# ---> 60     crowd = self._crowd_fn(F)
#      61     worst = int(np.argmin(crowd))
#      62     self.F.pop(worst)
#
# File ~\Desktop\VAMOS\src\vamos\algorithm\archive.py:18, in _single_front_crowding(F)
#      16     return np.empty(0, dtype=float)
#      17 fronts = [list(range(F.shape[0]))]
# ---> 18 return _compute_crowding(F, fronts)
#
# File ~\Desktop\VAMOS\src\vamos\kernel\numpy_backend.py:69, in _compute_crowding(F, fronts)
#      66 d = np.zeros(front_arr.size, dtype=float)
#      68 for m in range(n_obj):
# ---> 69     order = np.argsort(fvals[:, m], kind="mergesort")
#      70     sorted_vals = fvals[order, m]
#      72     d[order[0]] = np.inf
#
# File c:\Users\nicol\Desktop\VAMOS\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:1242, in argsort(a, axis, kind, order, stable)
#    1129 @array_function_dispatch(_argsort_dispatcher)
#    1130 def argsort(a, axis=-1, kind=None, order=None, *, stable=None):
#    1131     """
#    1132     Returns the indices that would sort an array.
#    1133
#    (...)   1240
#    1241     """
# -> 1242     return _wrapfunc(
#    1243         a, 'argsort', axis=axis, kind=kind, order=order, stable=stable
#    1244     )
#
# File c:\Users\nicol\Desktop\VAMOS\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)     64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
# Inspect and summarize tuning results
import json

def _to_serializable(obj):
    import numpy as np
    if hasattr(obj, 'to_dict'):
        return _to_serializable(obj.to_dict())
    if isinstance(obj, dict):
        return {k: _to_serializable(v) for k, v in obj.items()}
    if isinstance(obj, (list, tuple)):
        return [_to_serializable(v) for v in obj]
    if isinstance(obj, np.generic):
        return obj.item()
    return obj

trials_raw = tuning_results['trials']
print(f'Evaluated {len(trials_raw)} configurations (including duplicates)')

# Deduplicate by config to make the summary clearer
seen = set()
trials = []
for t in trials_raw:
    cfg_key = json.dumps(_to_serializable(t['config']), sort_keys=True)
    if cfg_key in seen:
        continue
    seen.add(cfg_key)
    trials.append(t)

print(f'Unique configurations: {len(trials)}')

# Sort by HV (meta objective stores negative HV in slot 0)
sorted_trials = sorted(trials, key=lambda t: t['objective'][0])
top_k = sorted_trials[:5]

def _summarize(cfg):
    pop = cfg.get('pop_size')
    cross = cfg.get('crossover', ['-', {}])
    mut = cfg.get('mutation', ['-', {}])
    return f"pop={pop}, cross={cross[0]}, mut={mut[0]}"

print('Top configs by HV:')
for rank, trial in enumerate(top_k, 1):
    obj = trial['objective']
    hv = -obj[0]
    time = obj[1]
    robust = obj[2]
    cfg = trial['config']
    summary = _summarize(cfg)
    print(f"#{rank}: HV={hv:.4f}, time={time:.3f}, robust={robust:.3f} | {summary}")

best = sorted_trials[0]
best_cfg = _to_serializable(best['config'])
best_hv = -best['objective'][0]
print('\nBest configuration details:')
print(f"HV={best_hv:.4f}")
print(json.dumps(best_cfg, indent=2))

# Save all trials (optional)
# trials_path = OUT_DIR / 'tuning_trials.json'
# with open(trials_path, 'w', encoding='utf-8') as fh:
#     json.dump(_to_serializable(tuning_results), fh, indent=2)
# print(f'Trials saved to {trials_path}')
# Out:
# Evaluated 60 configurations (including duplicates)
# Unique configurations: 30
# Top configs by HV:
# #1: HV=14.1013, time=1.185, robust=0.000 | pop=80, cross=spx, mut=uniform_reset
# #2: HV=13.4265, time=1.166, robust=0.000 | pop=80, cross=spx, mut=uniform_reset
# #3: HV=13.1617, time=1.165, robust=0.000 | pop=80, cross=spx, mut=uniform_reset
# #4: HV=10.9392, time=1.159, robust=0.000 | pop=80, cross=spx, mut=uniform_reset
# #5: HV=10.3129, time=1.147, robust=0.000 | pop=80, cross=spx, mut=uniform_reset
#
# Best configuration details:
# HV=14.1013
# {
#   "pop_size": 80,
#   "crossover": [
#     "spx",
#     {
#       "prob": 0.8258544383597095,
#       "epsilon": 0.261752260749445
#     }
#   ],
#   "mutation": [
#     "uniform_reset",
#     {
#       "prob": "1/n"
#     }
#   ],
#   "selection": [
#     "tournament",
#     {
#       "pressure": 2
#     }
#   ],
#   "survival": "nsga2",
#   "engine": "numpy",
#   "offspring_size": null,
#   "repair": null,
#   "archive": null
# }
